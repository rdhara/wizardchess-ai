# %%
# %load_ext autoreload

from os import environ, path

from pocketsphinx.pocketsphinx import *
from sphinxbase.sphinxbase import *

from pocketsphinx import DefaultConfig, Decoder, get_model_path, get_data_path

MODELDIR = get_model_path()
DATADIR = get_data_path()

MODELDIR
# Out:
# '/Users/apple/anaconda2/lib/python2.7/site-packages/pocketsphinx/model'

# %%
path.join(MODELDIR, 'chess-phone.lm')
# Out:
# '/Users/apple/anaconda2/lib/python2.7/site-packages/pocketsphinx/model/chess-phone.lm'

# %%
# Create a decoder with certain model
config = Decoder.default_config()
config.set_string('-hmm', os.path.join(MODELDIR, 'en-us'))
config.set_string('-allphone', os.path.join(MODELDIR, 'chess-phone.lm.bin'))
config.set_string('-dict', '/Users/apple/Desktop/16-17/CS182/chess-project/etc/chess-project.dic')
config.set_float('-lw', 2.0)
config.set_float('-beam', 1e-10)
config.set_float('-pbeam', 1e-10)

# Decode streaming data.
decoder = Decoder(config)

decoder.start_utt()
stream = open(path.join(DATADIR, 'training/rook_20.wav'), 'rb')
i=0
while True:
    buf = stream.read(1024)
    if buf:
        decoder.process_raw(buf, False, False)
    else:
        break
decoder.end_utt()

hypothesis = decoder.hyp()
print ('Phonemes: ', [seg.word for seg in decoder.seg()])
# Out:
# ('Phonemes: ', ['SIL', 'N', 'W', 'R', 'OW', 'R', 'OW', 'DH', 'ER', 'T', 'M', 'SIL'])

# %%
# Create a decoder with certain model
config = Decoder.default_config()
config.set_string('-hmm', os.path.join(MODELDIR, 'en-us-adapt'))
config.set_string('-allphone', os.path.join(MODELDIR, 'chess-phone.lm.bin'))
config.set_string('-dict', '/Users/apple/Desktop/16-17/CS182/chess-project/etc/chess-project.dic')
config.set_float('-lw', 2.0)
config.set_float('-beam', 1e-10)
config.set_float('-pbeam', 1e-10)

# Decode streaming data.
decoder = Decoder(config)

decoder.start_utt()
stream = open(path.join(DATADIR, 'training/rook_20.wav'), 'rb')
i=0
while True:
    buf = stream.read(1024)
    if buf:
        decoder.process_raw(buf, False, False)
    else:
        break
decoder.end_utt()

hypothesis = decoder.hyp()
print ('Phonemes: ', [seg.word for seg in decoder.seg()])
# Out:
# ('Phonemes: ', ['SIL', 'DH', 'R', 'W', 'R', 'AH', 'R', 'OW', 'UH', 'F', 'SIL'])

# %%
# Create a decoder with certain model
config = Decoder.default_config()
config.set_string('-hmm', path.join(MODELDIR, 'en-us'))
config.set_string('-allphone', path.join(MODELDIR, 'en-us-phone.lm.bin'))
config.set_string('-dict', '/Users/apple/Desktop/16-17/CS182/chess-project/etc/chess-project.dic')
config.set_float('-lw', 2.0)
config.set_float('-beam', 1e-10)
config.set_float('-pbeam', 1e-10)

# Decode streaming data.
decoder = Decoder(config)

decoder.start_utt()
stream = open(path.join(DATADIR, 'training/f_1.wav'), 'rb')
while True:
    buf = stream.read(1024)
    if buf:
        decoder.process_raw(buf, False, False)
    else:
        break
decoder.end_utt()

hypothesis = decoder.hyp()
print ('Phonemes: ', [seg.word for seg in decoder.seg()])
# Out:
# ('Phonemes: ', ['SIL', 'AE', 'AH', 'EY', '+SPN+', 'NG', 'HH'])

# %% [markdown]
# ## Duplicate data

# %%
import glob, os

# %%
def rename(dir, pattern, titlePattern):
    for pathAndFilename in glob.iglob(os.path.join(dir, pattern)):
        title, ext = os.path.splitext(os.path.basename(pathAndFilename))
        print(os.path.join(dir, titlePattern % title + ext))
        os.rename(pathAndFilename, 
                  os.path.join(dir, titlePattern % title + ext))

# %%
rename(r'/Users/apple/Desktop/16-17/CS182/chess-project/wav2', r'*.wav', r'%sb')
# Out:
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/1_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/2_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/3_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/4_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/5_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/6_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/7_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/8_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/a_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/b_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/bishop_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/c_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/castle_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/d_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/e_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/f_25b.wav
# ...
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queen_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/queenside_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/rook_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/takes_9b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_1b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_10b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_11b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_12b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_13b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_14b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_15b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_16b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_17b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_18b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_19b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_2b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_20b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_21b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_22b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_23b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_24b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_25b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_26b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_27b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_28b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_29b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_3b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_30b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_31b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_32b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_33b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_34b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_35b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_36b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_37b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_38b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_39b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_4b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_40b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_41b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_42b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_43b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_44b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_45b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_46b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_47b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_48b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_49b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_5b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_50b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_6b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_7b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_8b.wav
# /Users/apple/Desktop/16-17/CS182/chess-project/wav2/to_9b.wav

# %% [markdown]
# ### SOPHIE

# %%
#!/usr/bin/env python

from pocketsphinx.pocketsphinx import *
from sphinxbase.sphinxbase import *

import os
import pyaudio
import wave
import audioop
from collections import deque
import time
import math

from pocketsphinx import DefaultConfig, Decoder, get_model_path, get_data_path


"""
Written by Sophie Li, 2016
http://blog.justsophie.com/python-speech-to-text-with-pocketsphinx/
"""

class SpeechDetector:
    def __init__(self):
        # Microphone stream config.
        self.CHUNK = 1024  # CHUNKS of bytes to read each time from mic
        self.FORMAT = pyaudio.paInt16
        self.CHANNELS = 1
        self.RATE = 16000

        self.SILENCE_LIMIT = 1  # Silence limit in seconds. The max ammount of seconds where
                           # only silence is recorded. When this time passes the
                           # recording finishes and the file is decoded

        self.PREV_AUDIO = 0.5  # Previous audio (in seconds) to prepend. When noise
                          # is detected, how much of previously recorded audio is
                          # prepended. This helps to prevent chopping the beginning
                          # of the phrase.

        self.THRESHOLD = 4500
        self.num_phrases = -1

        # These will need to be modified according to where the pocketsphinx folder is
        MODELDIR = get_model_path()
        DATADIR = get_data_path()

        # Create a decoder with certain model
        config = Decoder.default_config()
        config.set_string('-hmm', os.path.join(MODELDIR, 'en-us'))
#         config.set_string('-lm', os.path.join(MODELDIR, 'en-us.lm.bin'))
#         config.set_string('-dict', os.path.join(MODELDIR, 'cmudict-en-us.dict'))
        config.set_string('-allphone', os.path.join(MODELDIR, 'chess-phone.lm.bin'))
#         config.set_float('-lw', 2.0)
#         config.set_float('-beam', 1e-10)
#         config.set_float('-pbeam', 1e-10)

        # Creaders decoder object for streaming data.
        self.decoder = Decoder(config)

    def setup_mic(self, num_samples=50):
        """ Gets average audio intensity of your mic sound. You can use it to get
            average intensities while you're talking and/or silent. The average
            is the avg of the .2 of the largest intensities recorded.
        """
        print "Getting intensity values from mic."
        p = pyaudio.PyAudio()
        stream = p.open(format=self.FORMAT, 
                        channels=self.CHANNELS,
                        rate=self.RATE, 
                        input=True, 
                        frames_per_buffer=self.CHUNK)

        values = [math.sqrt(abs(audioop.avg(stream.read(self.CHUNK), 4)))
                  for x in range(num_samples)]
        values = sorted(values, reverse=True)
        r = sum(values[:int(num_samples * 0.2)]) / int(num_samples * 0.2)
        print " Finished "
        print " Average audio intensity is ", r
        stream.close()
        p.terminate()

        if r < 3000:
            self.THRESHOLD = 3500
        else:
            self.THRESHOLD = r + 100

    def save_speech(self, data, p):
        """
        Saves mic data to temporary WAV file. Returns filename of saved
        file
        """
        filename = 'output_'+str(int(time.time()))
        # writes data to WAV file
        data = ''.join(data)
        wf = wave.open(filename + '.wav', 'wb')
        print('save_speech...')
        wf.setnchannels(1)
        wf.setsampwidth(p.get_sample_size(pyaudio.paInt16))
        wf.setframerate(16000)  # TODO make this value a function parameter?
        wf.writeframes(data)
        wf.close()
        return filename + '.wav'

    def decode_phrase(self, wav_file):
        self.decoder.start_utt()
        stream = open(wav_file, "rb")
        while True:
            buf = stream.read(1024)
            if buf:
                self.decoder.process_raw(buf, False, False)
            else:
                break
        self.decoder.end_utt()
        words = []
        [words.append(seg.word) for seg in self.decoder.seg()]
        return words

    def run(self):
        """
        Listens to Microphone, extracts phrases from it and calls pocketsphinx
        to decode the sound
        """
        self.setup_mic()

        #Open stream
        p = pyaudio.PyAudio()
        stream = p.open(format=self.FORMAT, 
                        channels=self.CHANNELS, 
                        rate=self.RATE, 
                        input=True, 
                        frames_per_buffer=self.CHUNK)
        print "* Mic set up and listening. "

        audio2send = []
        cur_data = ''  # current chunk of audio data
        rel = self.RATE/self.CHUNK
        slid_win = deque(maxlen=self.SILENCE_LIMIT * rel)
        #Prepend audio from 0.5 seconds before noise was detected
        prev_audio = deque(maxlen=self.PREV_AUDIO * rel)
        started = False

        while True:
            cur_data = stream.read(self.CHUNK)
            slid_win.append(math.sqrt(abs(audioop.avg(cur_data, 4))))
            
            thresh = sum([x > self.THRESHOLD for x in slid_win])
#             print 'threshold:{thresh}'.format(thresh=thresh)
            if thresh > 0:
                if started == False:
                    print "Starting recording of phrase"
                    started = True
                audio2send.append(cur_data)

            elif started:
                print "Finished recording, decoding phrase"
                filename = self.save_speech(list(prev_audio) + audio2send, p)
                r = self.decode_phrase(filename)
                print "DETECTED: ", r

                # Removes temp audio file
                os.remove(filename)
                # Reset all
                started = False
                slid_win = deque(maxlen=self.SILENCE_LIMIT * rel)
                prev_audio = deque(maxlen=0.5 * rel)
                audio2send = []
                print "Listening ..."

            else:
                prev_audio.append(cur_data)

        print "* Done listening"
        stream.close()
        p.terminate()

# %%
sd = SpeechDetector()
sd.run()
# Out:
# Getting intensity values from mic.
#  Finished
#  Average audio intensity is  1165.56710665
# * Mic set up and listening.
# Starting recording of phrase
# Finished recording, decoding phrase
# save_speech...
# DETECTED:  ['SIL', 'Z', 'K', 'S', 'Z', 'SIL', 'HH', 'L', 'EH', 'CH', 'D', 'HH', 'AH', 'K', 'S', 'AH', 'AH', 'AH', 'EH', 'SIL', 'EH', 'EY', 'AA', 'SIL', 'AE', 'V', 'TH', 'HH', 'AH', 'AH', 'NG']
# Listening ...
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-7-1d990713202b> in <module>()
#       1 sd = SpeechDetector()
# ----> 2 sd.run()
#
# <ipython-input-6-ade24bf4304c> in run(self)
#     140
#     141         while True:
# --> 142             cur_data = stream.read(self.CHUNK)
#     143             slid_win.append(math.sqrt(abs(audioop.avg(cur_data, 4))))
#     144
#
# /Users/apple/anaconda2/lib/python2.7/site-packages/PyAudio-0.2.9-py2.7-macosx-10.6-x86_64.egg/pyaudio.pyc in read(self, num_frames, exception_on_overflow)
#     606                           paCanNotReadFromAnOutputOnlyStream)
#     607
# --> 608         return pa.read_stream(self._stream, num_frames, exception_on_overflow)
#     609
#     610     def get_read_available(self):
#
# IOError: [Errno -9981] Input overflowed

# %%
pwd
# Out:
# u'/Users/apple/Desktop/16-17/CS182/chess-project'
